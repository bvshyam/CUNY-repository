# %% [markdown]
# Use the pandas module to answer the following questions about the EPA-HTTP data set.  Print the result of each part to the console.  Use pandas as much as you can; this includes the data structure and the analysis.
#
# Which hostname or IP address made the most requests?
# Which hostname or IP address received the most total bytes from the server?  How many bytes did it receive?
# During what hour was the server the busiest in terms of requests?  (You can do this by grouping each hour period e.g. 13:00 – 14:00. Then count the number of requests in each hour)
# Which .gif image was downloaded the most during the day?
# What HTTP reply codes were sent other than 200?
# Use any other tools or techniques you need to create an efficient program.  These include scipy, numpy, regex, Tkinter, etc.

# %%
import pandas as pd
import numpy as np

# %%
#df = pd.read_csv('data\\epa_http.txt', delimiter='r\s*\[\s*',names =None)

str1 = "141.243.1.172 [29:23:53:25] \"GET /Software.html HTTP/1.0\" 200 1497"
df = pd.read_csv('data\\epa_http.txt', sep=r'\s+')
df
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-53-6dc87f5399b7> in <module>()
#       2
#       3 str1 = "141.243.1.172 [29:23:53:25] \"GET /Software.html HTTP/1.0\" 200 1497"
# ----> 4 df = pd.read_csv('data\\epa_http.txt', sep=r'\s+')
#       5 df
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     644                     skip_blank_lines=skip_blank_lines)
#     645
# --> 646         return _read(filepath_or_buffer, kwds)
#     647
#     648     parser_f.__name__ = name
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     399         return parser
#     400
# --> 401     data = parser.read()
#     402     parser.close()
#     403     return data
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#     937                 raise ValueError('skipfooter not supported for iteration')
#     938
# --> 939         ret = self._engine.read(nrows)
#     940
#     941         if self.options.get('as_recarray'):
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1506     def read(self, nrows=None):
#    1507         try:
# -> 1508             data = self._reader.read(nrows)
#    1509         except StopIteration:
#    1510             if self._first_chunk:
#
# pandas\parser.pyx in pandas.parser.TextReader.read (pandas\parser.c:10415)()
#
# pandas\parser.pyx in pandas.parser.TextReader._read_low_memory (pandas\parser.c:10691)()
#
# pandas\parser.pyx in pandas.parser.TextReader._read_rows (pandas\parser.c:11437)()
#
# pandas\parser.pyx in pandas.parser.TextReader._tokenize_rows (pandas\parser.c:11308)()
#
# pandas\parser.pyx in pandas.parser.raise_parser_error (pandas\parser.c:27037)()
#
# CParserError: Error tokenizing data. C error: Expected 5 fields in line 7527, saw 6

# %%
#df = pd.read_csv('data\\epa_http.txt', delimiter='r\s*\[\s*',names =None)

str1 = "141.243.1.172 [29:23:53:25] \"GET /Software.html HTTP/1.0\" 200 1497"
df = pd.read_csv('data\\epa_http.txt', sep=r'\s*', usecols=range(0,10),engine='python')
df
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\pandas\io\parsers.py:1961: FutureWarning: split() requires a non-empty pattern match.
#   yield pat.split(line.strip())
# C:\Program Files\Anaconda3\lib\site-packages\pandas\io\parsers.py:1963: FutureWarning: split() requires a non-empty pattern match.
#   yield pat.split(line.strip())
#                          141.243.1.172  [29:23:53:25]   "GET  \
# 0              query2.lycos.cs.cmu.edu  [29:23:53:36]   "GET
# 1                     tanuki.twics.com  [29:23:53:53]   "GET
# 2                   wpbfl2-45.gate.net  [29:23:54:15]   "GET
# 3                   wpbfl2-45.gate.net  [29:23:54:16]   "GET
# 4                   wpbfl2-45.gate.net  [29:23:54:18]   "GET
# 5                       140.112.68.165  [29:23:54:19]   "GET
# 6                   wpbfl2-45.gate.net  [29:23:54:19]   "GET
# 7                   wpbfl2-45.gate.net  [29:23:54:19]   "GET
# 8                   wpbfl2-45.gate.net  [29:23:54:19]   "GET
# 9                     tanuki.twics.com  [29:23:54:19]   "GET
# 10                  wpbfl2-45.gate.net  [29:23:54:20]   "GET
# 11                    tanuki.twics.com  [29:23:54:25]   "GET
# 12                    tanuki.twics.com  [29:23:54:37]   "GET
# 13                  wpbfl2-45.gate.net  [29:23:54:37]   "GET
# 14                    tanuki.twics.com  [29:23:54:40]   "GET
# 15                  wpbfl2-45.gate.net  [29:23:55:01]   "GET
# 16             dd15-032.compuserve.com  [29:23:55:21]   "GET
# 17                    tanuki.twics.com  [29:23:55:23]   "GET
# 18                  wpbfl2-45.gate.net  [29:23:55:29]   "GET
# 19                      140.112.68.165  [29:23:55:33]   "GET
# 20                  wpbfl2-45.gate.net  [29:23:55:46]   "GET
# 21                  wpbfl2-45.gate.net  [29:23:55:47]   "GET
# 22                  wpbfl2-45.gate.net  [29:23:56:03]   "GET
# 23                  wpbfl2-45.gate.net  [29:23:56:12]   "GET
# 24                  wpbfl2-45.gate.net  [29:23:56:14]   "GET
# 25                    tanuki.twics.com  [29:23:56:24]   "GET
# 26                freenet2.carleton.ca  [29:23:56:36]   "GET
# 27                  wpbfl2-45.gate.net  [29:23:57:05]   "GET
# 28            ix-mia5-17.ix.netcom.com  [29:23:57:06]   "GET
# 29                  wpbfl2-45.gate.net  [29:23:57:08]  "POST
# ...                                ...            ...    ...
# 47717             jhws19.aca.ilstu.edu  [30:23:51:30]   "GET
# 47718             jhws19.aca.ilstu.edu  [30:23:51:30]   "GET
# 47719             jhws19.aca.ilstu.edu  [30:23:51:31]   "GET
# 47720             jhws19.aca.ilstu.edu  [30:23:51:31]   "GET
# 47721             www-e5.proxy.aol.com  [30:23:51:31]   "GET
# 47722         edmonton-3.slip.uiuc.edu  [30:23:51:35]   "GET
# 47723                   204.188.47.212  [30:23:51:41]   "GET
# 47724  cust60.max1.denver.co.ms.uu.net  [30:23:51:46]   "GET
# 47725         edmonton-3.slip.uiuc.edu  [30:23:51:54]   "GET
# 47726  cust60.max1.denver.co.ms.uu.net  [30:23:51:56]   "GET
# 47727             www-e5.proxy.aol.com  [30:23:51:57]   "GET
# 47728             www-e5.proxy.aol.com  [30:23:51:59]   "GET
# 47729   sebastion-gw.environ.wa.gov.au  [30:23:52:00]   "GET
# 47730                   204.188.47.212  [30:23:52:06]   "GET
# 47731             www-e5.proxy.aol.com  [30:23:52:08]   "GET
# 47732             www-e5.proxy.aol.com  [30:23:52:10]   "GET
# 47733   sebastion-gw.environ.wa.gov.au  [30:23:52:12]   "GET
# 47734                   139.230.166.82  [30:23:52:15]   "GET
# 47735                   204.188.47.212  [30:23:52:21]   "GET
# 47736             www-e5.proxy.aol.com  [30:23:52:39]   "GET
# 47737             jhws19.aca.ilstu.edu  [30:23:52:42]   "GET
# 47738             jhws19.aca.ilstu.edu  [30:23:52:42]   "GET
# 47739             jhws19.aca.ilstu.edu  [30:23:52:43]   "GET
# 47740             jhws19.aca.ilstu.edu  [30:23:52:43]   "GET
# 47741             jhws19.aca.ilstu.edu  [30:23:52:44]   "GET
# 47742             jhws19.aca.ilstu.edu  [30:23:52:44]   "GET
# 47743             jhws19.aca.ilstu.edu  [30:23:52:44]   "GET
# 47744             jhws19.aca.ilstu.edu  [30:23:52:45]   "GET
# 47745             www-e5.proxy.aol.com  [30:23:53:06]   "GET
# 47746             jhws19.aca.ilstu.edu  [30:23:53:07]   "GET
#
#                                           /Software.html  HTTP/1.0"  200  \
# 0                                         /Consumer.html  HTTP/1.0"  200
# 1                                             /News.html  HTTP/1.0"  200
# 2                                                      /  HTTP/1.0"  200
# 3                           /icons/circle_logo_small.gif  HTTP/1.0"  200
# 4                                /logos/small_gopher.gif  HTTP/1.0"  200
# 5                                     /logos/us-flag.gif  HTTP/1.0"  200
# 6                                   /logos/small_ftp.gif  HTTP/1.0"  200
# 7                                        /icons/book.gif  HTTP/1.0"  200
# 8                                     /logos/us-flag.gif  HTTP/1.0"  200
# 9                          /docs/OSWRCRA/general/hotline  HTTP/1.0"  302
# 10                                      /icons/ok2-0.gif  HTTP/1.0"  200
# 11                             /OSWRCRA/general/hotline/  HTTP/1.0"  200
# 12                /docs/OSWRCRA/general/hotline/95report  HTTP/1.0"  302
# 13                           /docs/browner/adminbio.html  HTTP/1.0"  200
# 14                    /OSWRCRA/general/hotline/95report/  HTTP/1.0"  200
# 15                             /docs/browner/cbpress.gif  HTTP/1.0"  200
# 16                            /Access/chapter1/s2-4.html  HTTP/1.0"  200
# 17     /docs/OSWRCRA/general/hotline/95report/05_95mh...  HTTP/1.0"  200
# 18                                          /docs/Access  HTTP/1.0"  302
# 19                                    /logos/us-flag.gif  HTTP/1.0"  200
# 20                                     /information.html  HTTP/1.0"  200
# 21                                     /icons/people.gif  HTTP/1.0"  200
# 22                                          /docs/Access  HTTP/1.0"  302
# 23                                              /Access/  HTTP/1.0"  200
# 24                            /Access/images/epaseal.gif  HTTP/1.0"  200
# 25                    /OSWRCRA/general/hotline/95report/  HTTP/1.0"  200
# 26                              /emap/html/regions/four/  HTTP/1.0"  200
# 27                                /waisicons/unknown.gif  HTTP/1.0"  200
# 28                                                /OWOW/  HTTP/1.0"  200
# 29     /cgi-bin/waisgate/134.67.99.11=earth1.epa.gov=...  HTTP/1.0"  200
# ...                                                  ...        ...  ...
# 47717                              /cgi-bin/thiefclr.gif  HTTP/1.0"  404
# 47718                              /cgi-bin/env_logo.gif  HTTP/1.0"  404
# 47719                                    /logos/nsdi.gif  HTTP/1.0"  200
# 47720                            /gumpo/gif/epa_logo.gif  HTTP/1.0"  200
# 47721                               /icons/large_epa.gif  HTTP/1.0"  200
# 47722                          /enviro/html/ef_home.html  HTTP/1.0"  200
# 47723                              /OWOW/regs/reg10.html  HTTP/1.0"  200
# 47724                                                  /  HTTP/1.0"  200
# 47725               /enviro/html/tris/tris_overview.html  HTTP/1.0"  200
# 47726                       /icons/circle_logo_small.gif  HTTP/1.0"  304
# 47727                                         /docs/hrmd  HTTP/1.0"  302
# 47728                                             /hrmd/  HTTP/1.0"  200
# 47729                                      /Techlibrary/  HTTP/1.0"  200
# 47730                              /OWOW/sec8/index.html  HTTP/1.0"  200
# 47731                                 /docs/hrmd/vacancy  HTTP/1.0"  302
# 47732                                     /hrmd/vacancy/  HTTP/1.0"  200
# 47733                       /icons/circle_logo_small.gif  HTTP/1.0"  200
# 47734                           /docs/Fall94/05.txt.html  HTTP/1.0"  200
# 47735                               /OWOW/sec7/rwrb.html  HTTP/1.0"  200
# 47736                /docs/hrmd/vacancy/metavac.txt.html  HTTP/1.0"  200
# 47737                                  /cgi-bin/line.gif  HTTP/1.0"  404
# 47738                                   /cgi-bin/ed4.gif  HTTP/1.0"  404
# 47739                               /cgi-bin/at-work.gif  HTTP/1.0"  404
# 47740                              /cgi-bin/thiefclr.gif  HTTP/1.0"  404
# 47741                                   /cgi-bin/del.gif  HTTP/1.0"  404
# 47742                              /cgi-bin/env_logo.gif  HTTP/1.0"  404
# 47743                            /gumpo/gif/epa_logo.gif  HTTP/1.0"  200
# 47744                                    /logos/nsdi.gif  HTTP/1.0"  200
# 47745                      /docs/hrmd/vacancy/index.html  HTTP/1.0"  200
# 47746  /cgi-bin/waisgate?port=210&ip_address=earth1&d...  HTTP/1.0"  200
#
#         1497
# 0       1325
# 1       1014
# 2       4889
# 3       2624
# 4        935
# 5       2788
# 6        124
# 7        156
# 8       2788
# 9          -
# 10       231
# 11       991
# 12         -
# 13      4217
# 14      1250
# 15     51661
# 16      4602
# 17     56431
# 18         -
# 19      2788
# 20       617
# 21       224
# 22         -
# 23      2376
# 24      2624
# 25      1250
# 26     15173
# 27        83
# 28      1501
# 29     26217
# ...      ...
# 47717      -
# 47718      -
# 47719  29838
# 47720   1104
# 47721    647
# 47722   4374
# 47723   2131
# 47724   4950
# 47725   2408
# 47726      0
# 47727      -
# 47728    655
# 47729    893
# 47730   1204
# 47731      -
# 47732    971
# 47733   2624
# 47734   6129
# 47735   3391
# 47736   1519
# 47737      -
# 47738      -
# 47739      -
# 47740      -
# 47741      -
# 47742      -
# 47743   1104
# 47744  29838
# 47745    971
# 47746   5719
#
# [47747 rows x 7 columns]

# %%
#df = pd.read_csv('data\\epa_http.txt', delimiter='r\s*\[\s*',names =None)

str1 = "141.243.1.172 [29:23:53:25] \"GET /Software.html HTTP/1.0\" 200 1497"
df = pd.read_csv(str1, sep='r\s*\[\s*)
df
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-51-cb425de60946> in <module>()
#       2
#       3 str1 = "141.243.1.172 [29:23:53:25] \"GET /Software.html HTTP/1.0\" 200 1497"
# ----> 4 df = pd.read_csv(str1, sep='r\s+')
#       5 df
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     644                     skip_blank_lines=skip_blank_lines)
#     645
# --> 646         return _read(filepath_or_buffer, kwds)
#     647
#     648     parser_f.__name__ = name
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     387
#     388     # Create the parser.
# --> 389     parser = TextFileReader(filepath_or_buffer, **kwds)
#     390
#     391     if (nrows is not None) and (chunksize is not None):
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     728             self.options['has_index_names'] = kwds['has_index_names']
#     729
# --> 730         self._make_engine(self.engine)
#     731
#     732     def close(self):
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#     927             elif engine == 'python-fwf':
#     928                 klass = FixedWidthFieldParser
# --> 929             self._engine = klass(self.f, **self.options)
#     930
#     931     def _failover_to_python(self):
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, **kwds)
#    1797             f = _get_handle(f, 'r', encoding=self.encoding,
#    1798                             compression=self.compression,
# -> 1799                             memory_map=self.memory_map)
#    1800             self.handles.append(f)
#    1801         elif self.compression:
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path, mode, encoding, compression, memory_map)
#     330                 f = open(path, mode, encoding=encoding)
#     331             else:
# --> 332                 f = open(path, mode, errors='replace')
#     333         else:
#     334             f = open(path, mode)
#
# OSError: [Errno 22] Invalid argument: '141.243.1.172 [29:23:53:25] "GET /Software.html HTTP/1.0" 200 1497'
