# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
river = pd.read_csv("https://raw.githubusercontent.com/charleyferrari/CUNY_DATA608/master/lecture4/Data/riverkeeper_data_2013.csv", sep=",")
river['Date'] = pd.to_datetime(river.Date)

#river.set_index('Date', inplace= True)

river['EnteroCount'] = pd.to_numeric(pd.Series(river['EnteroCount'].str.replace('>|<',"")))

#print(river['EnteroCount'] )

#river[river.index < '20080101']

#river.loc['20100102':'20130104']
river.describe()
river.head()
river_pb1 = river
river_water = river

# %%
#Best places to swim


river_pb1['DayRain_ml'] = (river_pb1['FourDayRainTotal']/4)*16.3872
river_pb1['average'] = river_pb1['EnteroCount']/river_pb1['DayRain_ml']
river_pb1.describe()
print(river_pb1[river_pb1['Site']=='Hudson above Mohawk River'].describe())
# Out:
#        EnteroCount  FourDayRainTotal  SampleCount  DayRain_ml    average
# count    35.000000         35.000000         35.0   35.000000  35.000000
# mean    223.685714          0.631429         35.0    2.586837        inf
# std     622.342150          0.755673          0.0    3.095842        NaN
# min       1.000000          0.000000         35.0    0.000000   0.813643
# 25%      10.500000          0.050000         35.0    0.204840   8.136432
# 50%      15.000000          0.200000         35.0    0.819360  26.850225
# 75%      31.000000          1.350000         35.0    5.530680        inf
# max    2420.000000          2.800000         35.0   11.471040        inf
# C:\Program Files\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3817: RuntimeWarning: invalid value encountered in multiply
#   x2 = take(ap, indices_above, axis=axis) * weights_above

# %%
#print(river[river['Site']=='Hudson above Mohawk River'].describe())
#river["Site"] = river["Site"].astype('category')
#print(river.groupby('Site').describe())
river_new = river.groupby('Site').agg(['mean','count'])
(river_new['EnteroCount']['count']< 5) & (river_new['EnteroCount']['mean'] > 110)

#np.where(river_new['EnteroCount']['count'] < 5 )

river_new['swim'] = np.where(
    ((river_new['EnteroCount']['count']< 5) & (river_new['EnteroCount']['mean'] > 110)) |
    ((river_new['EnteroCount']['count'] > 5) & (river_new['EnteroCount']['mean'] > 30)), 
    'unacceptable', 'acceptable')
river_new
# Out:
#                                          EnteroCount       FourDayRainTotal  \
#                                                 mean count             mean
# Site
# 125th St. Pier                            179.696970    66         0.771212
# 79th St. mid-channel                       47.204082    49         0.861224
# Albany Rowing Dock                        280.944444    36         0.630556
# Annesville Creek                           83.421053    38         0.484211
# Athens                                    201.314286    35         0.597143
# Beacon Harbor                              52.657895    38         0.368421
# Bethlehem Launch Ramp                     231.694444    36         0.569444
# Castle Point, NJ                           37.076923    39         0.664103
# Castleton                                 186.000000    35         0.588571
# Catskill Creek- East End                  261.238095    42         0.578571
# Catskill Creek- First Bridge              305.947368    38         0.600000
# Catskill Launch Ramp                      132.378378    37         0.605405
# Cedar Pond Brook                          199.702128    47         0.482979
# Coeymans Landing                          186.555556    36         0.594444
# Cold Spring Harbor                         22.542857    35         0.305714
# Congress St. Bridge- Troy                 247.315789    38         0.626316
# Coxsackie Waterfront Park                 170.457143    35         0.605714
# Croton Point Beach                         15.458333    48         0.464583
# Dunn Memorial Bridge- Albany              357.973684    38         0.626316
# Dyckman Street Beach                       30.236842    38         0.676316
# East River mid-channel at 23rd St.         45.340000    50         0.766000
# East River mid-channel at Roosevelt Is.    48.250000    48         0.797917
# Emeline Beach- Haverstraw                 298.078947    38         0.484211
# Esopus Creek Entrance                     263.558140    43         0.506977
# Esopus Creek West                         224.571429    42         0.464286
# Fort Montgomery                            88.138889    36         0.302778
# Furnace Brook                             172.520833    48         0.466667
# GW Bridge mid-channel                      58.183673    49         0.824490
# Newtown Creek- Dutch Kills                 57          57    57   3.493061
# Newtown Creek- Metropolitan Ave. Bridge    57          57    57   3.493061
# Norrie Point Yacht Basin                   36          36    36   1.274560
# Norrie Point mid-channel                   36          36    36   1.274560
# North River STP at 145th                   47          47    47   3.486638
# Nyack Launch Ramp                          61          61    61   2.075264
# Orangetown STP Outfall                     57          57    57   2.522766
# Ossining Beach                             47          47    47   1.874068
# Peekskill Riverfront Green Park            42          42    42   1.950857
# Pier 96 Kayak Launch                       39          39    39   2.762714
# Piermont Pier                             187         187   187   2.186421
# Port Ewen Drinking Water Intake            37          37    37   1.428344
# Poughkeepsie Drinking Water Intake         38          38    38   1.433880
# Poughkeepsie Launch Ramp                   37          37    37   1.306547
# Rondout- Eddyville Anchorage               45          45    45   1.502160
# Rondout- Kingston Public Dock              39          39    39   1.397114
# Saw Mill River                             50          50    50   3.039826
# Stony Point mid-channel                    44          44    44   1.890115
# TZ Bridge mid-channel                      57          57    57   2.874947
# Tarrytown Marina                           27          27    27   3.338133
# The Battery mid-channel                    49          49    49   3.519904
# Tivoli Landing                             37          37    37   1.694082
# Ulster Landing Beach                       36          36    36   1.399740
# Upper Sparkill Creek                      165         165   165   2.155165
# Wappingers Creek                           35          35    35   1.193925
# West Point STP Outfall                     36          36    36   1.149380
# Yonkers STP Outfall                        51          51    51   3.020386
# Yonkers mid-channel                        52          52    52   3.017451
#
#                                               average                swim
#                                         count    mean count
# Site
# 125th St. Pier                             66     inf    66  unacceptable
# 79th St. mid-channel                       49     inf    49  unacceptable
# Albany Rowing Dock                         36     inf    36  unacceptable
# Annesville Creek                           38     inf    38  unacceptable
# Athens                                     35     inf    35  unacceptable
# Beacon Harbor                              38     inf    38  unacceptable
# Bethlehem Launch Ramp                      36     inf    36  unacceptable
# Castle Point, NJ                           39     inf    39  unacceptable
# Castleton                                  35     inf    35  unacceptable
# Catskill Creek- East End                   42     inf    42  unacceptable
# Catskill Creek- First Bridge               38     inf    38  unacceptable
# Catskill Launch Ramp                       37     inf    37  unacceptable
# Cedar Pond Brook                           47     inf    47  unacceptable
# Coeymans Landing                           36     inf    36  unacceptable
# Cold Spring Harbor                         35     inf    35    acceptable
# Congress St. Bridge- Troy                  38     inf    38  unacceptable
# Coxsackie Waterfront Park                  35     inf    35  unacceptable
# Croton Point Beach                         48     inf    48    acceptable
# Dunn Memorial Bridge- Albany               38     inf    38  unacceptable
# Dyckman Street Beach                       38     inf    38  unacceptable
# East River mid-channel at 23rd St.         50     inf    50  unacceptable
# East River mid-channel at Roosevelt Is.    48     inf    48  unacceptable
# Emeline Beach- Haverstraw                  38     inf    38  unacceptable
# Esopus Creek Entrance                      43     inf    43  unacceptable
# Esopus Creek West                          42     inf    42  unacceptable
# Fort Montgomery                            36     inf    36  unacceptable
# Furnace Brook                              48     inf    48  unacceptable
# GW Bridge mid-channel                      49     inf    49  unacceptable
# Gay's Point mid-channel                    36     inf    36  unacceptable
# Gowanus Canal                              37     inf    37  unacceptable
# ...                                       ...     ...   ...           ...
# Mohawk River at Waterford                  35     inf    35  unacceptable
# Newburgh Launch Ramp                       38     inf    38  unacceptable
# Newtown Creek- Dutch Kills                 57     inf    57  unacceptable
# Newtown Creek- Metropolitan Ave. Bridge    57     inf    57  unacceptable
# Norrie Point Yacht Basin                   36     inf    36  unacceptable
# Norrie Point mid-channel                   36     inf    36  unacceptable
# North River STP at 145th                   47     inf    47  unacceptable
# Nyack Launch Ramp                          61     inf    61  unacceptable
# Orangetown STP Outfall                     57     inf    57  unacceptable
# Ossining Beach                             47     inf    47  unacceptable
# Peekskill Riverfront Green Park            42     inf    42  unacceptable
# Pier 96 Kayak Launch                       39     inf    39  unacceptable
# Piermont Pier                             187     inf   187  unacceptable
# Port Ewen Drinking Water Intake            37     inf    37  unacceptable
# Poughkeepsie Drinking Water Intake         38     inf    38    acceptable
# Poughkeepsie Launch Ramp                   37     inf    37    acceptable
# Rondout- Eddyville Anchorage               45     inf    45  unacceptable
# Rondout- Kingston Public Dock              39     inf    39  unacceptable
# Saw Mill River                             50     inf    50  unacceptable
# Stony Point mid-channel                    44     inf    44    acceptable
# TZ Bridge mid-channel                      57     inf    57    acceptable
# Tarrytown Marina                           27     inf    27  unacceptable
# The Battery mid-channel                    49     inf    49  unacceptable
# Tivoli Landing                             37     inf    37  unacceptable
# Ulster Landing Beach                       36     inf    36  unacceptable
# Upper Sparkill Creek                      165     inf   165  unacceptable
# Wappingers Creek                           35     inf    35  unacceptable
# West Point STP Outfall                     36     inf    36  unacceptable
# Yonkers STP Outfall                        51     inf    51  unacceptable
# Yonkers mid-channel                        52     inf    52    acceptable
#
# [75 rows x 11 columns]

# %%
#plt.plot(river_new['EnteroCount']['count'],river_new['EnteroCount']['mean'] )
#plt.plot(river_new['count'],river_new['EnteroCount']['mean'] )
#plt.show()

#x = np.random.normal(size=100)
#sns.distplot(x, kde=True, rug=True)

# %% [markdown]
# - The testing of water quality can be sporadic. Which sites have been tested most regularly?
# Which ones have long gaps between tests? Pick out 5-10 sites and visually compare how
# regularly their water quality is tested.

# %%
river_water = river

# %%
river_water_hudson = river_water[river_water['Site'] =="Hudson above Mohawk River"]
river_water_hudson = river_water_hudson.sort_values('Date',ascending=False)

river_water_hudson['Date'] = pd.to_datetime(river_water_hudson['Date'])

river_water_hudson=river_water_hudson.reset_index(drop=True)

#river_water_hudson[1::1]['Date_1'] = river_water_hudson[2::1]['Date']

# %%
river_water_hudson['Diff'] = (river_water_hudson['Date'] - river_water_hudson['Date'].shift(-1)).astype('str'). \
                            str.replace("\D{3}","")

days_diff = pd.Series(river_water_hudson['Diff'] )
days_diff
# Out:
# 0      3000:00:00.000000000
# 1      3300:00:00.000000000
# 2      2900:00:00.000000000
# 3      2700:00:00.000000000
# 4      2000:00:00.000000000
# 5     23200:00:00.000000000
# 6      3000:00:00.000000000
# 7      2800:00:00.000000000
# 8      2800:00:00.000000000
# 9      3500:00:00.000000000
# 10     2700:00:00.000000000
# 11    21700:00:00.000000000
# 12     2700:00:00.000000000
# 13     2900:00:00.000000000
# 14     3800:00:00.000000000
# 15     1200:00:00.000000000
# 16     4400:00:00.000000000
# 17    21500:00:00.000000000
# 18     3200:00:00.000000000
# 19     2400:00:00.000000000
# 20     3300:00:00.000000000
# 21     3100:00:00.000000000
# 22     2400:00:00.000000000
# 23    21400:00:00.000000000
# 24     3600:00:00.000000000
# 25     2400:00:00.000000000
# 26     2400:00:00.000000000
# 27     7700:00:00.000000000
# 28    20400:00:00.000000000
# 29     3500:00:00.000000000
# 30     4000:00:00.000000000
# 31     2300:00:00.000000000
# 32     2800:00:00.000000000
# 33     2800:00:00.000000000
# 34
# Name: Diff, dtype: object
